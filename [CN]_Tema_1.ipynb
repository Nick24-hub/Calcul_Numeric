# %% [markdown]
# <a href="https://colab.research.google.com/github/Nick24-hub/Calcul_Numeric/blob/main/%5BCN%5D_Tema_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Calcul Numeric - Tema nr. 1

# %% [markdown]
# ### Exercitiul 1
#
# Sa se gaseasca cel mai mic numar pozitiv $u > 0$, de forma $u = 10^{−m}$,
# astfel incat:
#
# $$1.0 +_c u \neq 1.0$$
#
# unde prin $+c$ am notat operatia de adunare efectuata de calculator.
#
# Numarul u poarta numele de precizia masina.

# %%
from tema1 import get_u

u = get_u()
print(f"Precizia masina este {u}")
# Out:
# Precizia masina este 1e-15

# %% [markdown]
# ### Exercitiul 2
#
# Operatia $+_c$ este neasociativa: fie numerele reale $a = 1.0, b = u/10,
# c = u/10$, unde u este precizia masina calculata anterior. Sa se verifice
# ca operatia de adunare efectuata de calculator nu este asociativa, i.e.:
#
# $$(a +_c b) +_c c \neq a +_c (b +_c c)$$
#
# Gasiti un exemplu pentru care operatia $\times_c$ nu este asociativa.

# %%
a = 1.0
b = u / 10
c = u / 10

(a + b) + c, a + (b + c)
# Out:
# (1.0, 1.0000000000000002)

# %% [markdown]
# Exemplu pentru cand inmultirea ($\times_c$) nu e este asociativa.

# %%
from tema1 import numere_inmultite_non_asociative

a, b, c = numere_inmultite_non_asociative()

print(f"a={a}")
print(f"b={b}")
print(f"c={c}")

f"(a * b) * c, a * (b * c) = {(a * b) * c}, {a * (b * c)}"
# Out:
# a=0.5833820394550312
# b=0.9081128851953352
# c=0.5046868558173903
# '(a * b) * c, a * (b * c) = 0.2673713607390154, 0.26737136073901546'

# %% [markdown]
# ### Exercitiul 3 - Aproximarea unor functii elementare

# %% [markdown]
# Implementaţi următoarele metode de aproximare a valorilor funcţilor sinus, cosinus şi logaritm natural.
#
#
# $$\sin \left(\frac{1}{4} \pi x\right) \approx x \frac{P_{4}\left(x^{2}\right)}{Q_{4}\left(x^{2}\right)} \quad, \quad \textbf{pentru } -1 \leq x \leq 1$$
#
#
#
# $$\cos \left(\frac{1}{4} \pi x\right) \approx \frac{P_{4}\left(x^{2}\right)}{Q_{4}\left(x^{2}\right)} \quad, \quad \textbf{pentru } -1 \leq x \leq 1$$
#
# $$\ln (x) \quad \approx z \frac{P_{4}\left(z^{2}\right)}{Q_{4}\left(z^{2}\right)} \quad, \quad \textbf{unde } z=\frac{x-1}{x+1} \textbf{ şi }\frac{1}{\sqrt{2}} \leq x \leq \sqrt{2}$$
# Polinoamele din formulele de mai sus se calculează folosind următoarele relatii:
# $$
# \begin{aligned}
# &P_{4}(y)=a_{0}+y\left(a_{1}+y\left(a_{2}+y\left(a_{3}+y a_{4}\right)\right)\right) \\
# &Q_{4}(y)=b_{0}+y\left(b_{1}+y\left(b_{2}+y\left(b_{3}+y b_{4}\right)\right)\right)
# \end{aligned}
# $$
#
# Pentru fiecare din funcţile sinus, cosinus şi logaritm natural, mulţimea coeficienţilor $\left\{a_{i} ; i=0, \ldots, 4\right\},\left\{b_{i} ; i=0, \ldots, 4\right\}$ este diferită.
#
# Coeficientii sunt definiti in urmatoarea celula.
#
# Pentru a evita împărţirile cu valori apropiate de 0 în calculele de mai sus, numărătorii care au modulul mai mic decât $10^{-12}$ vor fi înlocuiţi cu $10^{-12}$.
#
# Pentru fiecare funcţie, afişaţi argumentul funcţiei, valoarea calculată cu formulele de mai sus, valoarea funcţiei corespunzătoare din biblioteca matematică (pentru acelaşi argument) şi modulul diferenţei dintre valoarea calculată de voi şi cea cu biblioteca matematică.
#
# Bonus 10 pt. : Pentru functiile sinus şi cosinus, folosind periodicitatea lor şi alte relaţii ale funcţilor trigonometrice, calculaţi valorile lor pentru orice argument real, nu doar pentru cele din intervalul $\left[-\frac{\pi}{4}, \frac{\pi}{4}\right] .$

# %%
def sin_coef():
  a = [
      1805490264.690988571178600370234394843221,
      -164384678.227499837726129612587952660511,  
      3664210.647581261810227924465160827365,
      -28904.140246461781357223741935980097,
      76.568981088717405810132543523682
  ]
  b = [
      2298821602.638922662086487520330827251172, 
      27037050.118894436776624866648235591988,
      155791.388546947693206469423979505671,
      540.567501261284024767779280700089,
      1.0 
  ]
  return a, b

       
def cos_coef():
  a = [
      1090157078.174871420428849017262549038606,
      -321324810.993150712401352959397648541681,
      12787876.849523878944051885325593878177,
      -150026.206045948110568310887166405972,
      538.333564203182661664319151379451,   
  ]

  b = [
    1090157078.174871420428867295670039506886,
    14907035.776643879767410969509628406502,
    101855.811943661368302608146695082218,
    429.772865107391823245671264489311,
    1.0,
  ]

  return a, b

def ln_coef():
  a = [
    75.151856149910794642732375452928,
    -134.730399688659339844586721162914, 
    74.201101420634257326499008275515, 
    -12.777143401490740103758406454323, 
    0.332579601824389206151063529971,  
  ]

  b = [
    37.575928074955397321366156007781, 
    -79.890509202648135695909995521310,  
    56.215534829542094277143417404711, 
    -14.516971195056682948719125661717, 
    1.0 
  ]
  return a, b

# %% [markdown]
# Imports required for plots

# %%
import plotly.graph_objects as go
import numpy as np

# %% [markdown]
# ### Aproximare sinus

# %%
from tema1 import approx_sin

x = np.linspace(-10, 10, 1000)

y = [approx_sin(x_value) for x_value in x]
fig = go.Figure(data=go.Scatter(x=x, y=y, name="polynomial approx method"))

y = [np.sin(x_value) for x_value in x]
fig.add_trace(go.Scatter(x=x, y=y, name="numpy sin method"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="380cf19e-787d-44f7-8d39-3534715c098c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("380cf19e-787d-44f7-8d39-3534715c098c")) {                    Plotly.newPlot(                        "380cf19e-787d-44f7-8d39-3534715c098c",                        [{"name":"polynomial approx method","x":[-10.0,-9.97997997997998,-9.95995995995996,-9.93993993993994,-9.91991991991992,-9.8998998998999,-9.87987987987988,-9.85985985985986,-9.83983983983984,-9.81981981981982,-9.7997997997998,-9.77977977977978,-9.75975975975976,-9.73973973973974,-9.71971971971972,-9.6996996996997,-
# %% [markdown]
# ### Aproximarea functiei cosinus

# %%
from tema1 import approx_cos

x = np.linspace(-10, 10, 100)

y = [approx_cos(x_value) for x_value in x]
fig = go.Figure(data=go.Scatter(x=x, y=y, name="polynomial approx method"))

y = [np.cos(x_value) for x_value in x]
fig.add_trace(go.Scatter(x=x, y=y, name="numpy cos method"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d92af3d8-450f-42ef-bdc4-f9a3ef03aad3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d92af3d8-450f-42ef-bdc4-f9a3ef03aad3")) {                    Plotly.newPlot(                        "d92af3d8-450f-42ef-bdc4-f9a3ef03aad3",                        [{"name":"polynomial method","x":[-10.0,-9.797979797979798,-9.595959595959595,-9.393939393939394,-9.191919191919192,-8.98989898989899,-8.787878787878787,-8.585858585858587,-8.383838383838384,-8.181818181818182,-7.979797979797979,-7.777777777777778,-7.575757575757576,-7.373737373737374,-7.171717171717171,-6.96969696969697,-6.767676767676768,-6.565656565656566,-6.363636363636363,-6.161616161616162,-5.959595959595959,-5.757575757575758,-5.555555555555555,-5.353535353535354,-5.151515151515151,-4.94949494949495,-4.747474747474747,-4.545454545454546,-4.343434343434343,-4.141414141414142,-3.9393939393939394,-3.737373737373738,-3.5353535353535355,-3.333333333333333,-3.1313131313131315,-2.929292929292929,-2.7272727272727275,-2.525252525252525,-2.3232323232323235,-2.121212121212121,-1.9191919191919187,-1.717171717171718,-1.5151515151515156,-1.3131313131313131,-1.1111111111111107,-0.9090909090909101,-0.7070707070707076,-0.5050505050505052,-0.30303030303030276,-0.10101010101010033,0.10101010101010033,0.30303030303030276,0.5050505050505052,0.7070707070707076,0.9090909090909083,1.1111111111111107,1.3131313131313131,1.5151515151515156,1.7171717171717162,1.9191919191919187,2.121212121212121,2.3232323232323235,2.525252525252524,2.7272727272727266,2.929292929292929,3.1313131313131315,3.333333333333334,3.5353535353535346,3.737373737373737,3.9393939393939394,4.141414141414142,4.3434343434343425,4.545454545454545,4.747474747474747,4.94949494949495,5.1515151515151505,5.353535353535353,5.555555555555555,5.757575757575758,5.9595959595959584,6.161616161616163,6.363636363636363,6.565656565656564,6.767676767676768,6.969696969696969,7.171717171717173,7.373737373737374,7.575757575757574,7.777777777777779,7.979797979797979,8.18181818181818,8.383838383838384,8.585858585858585,8.787878787878789,8.98989898989899,9.19191919191919,9.393939393939394,9.595959595959595,9.7979797979798,10.0],"y":[2.0342435296098578,1.3736074609067492,0.8450678705768769,0.4392876314015445,0.1458752000017159,-0.04649429488498104,-0.14992844479529244,-0.17713859798463252,-0.1412348689711009,-0.055498684180519,0.0668623246868463,0.21297106809641225,0.3705422947372685,0.5281404557784579,0.6754255326908036,0.8033779281448229,0.9044936036582866,0.9729411457323485,1.0046733660838416,0.9974873783526765,0.9510288045601419,0.8667377858515952,0.7477367177830418,0.5986619972361811,0.42544444119694164,0.23504529791349657,0.035156802059452895,-0.16612207889427735,-0.3606227900166336,-0.5404445336423997,-0.6982788847513993,-0.8277090681799459,-0.9234721556075498,-0.9816738185577513,-0.9999471047234172,-0.977548909967344,-0.9153903026098982,-0.8159995139816637,-0.6834191270255328,-0.5230416586272608,-0.3413902300419743,-0.14585324951336198,0.05561610016586629,0.25482334572605125,0.44366602170222896,0.6144632264484666,0.7602680316591502,0.8751500385908233,0.9544365884201448,0.9949028158568305,0.9949028158568305,0.9544365884201448,0.8751500385908233,0.7602680316591502,0.614463226448468,0.44366602170222896,0.25482334572605125,0.05561610016586629,-0.1458532495133604,-0.3413902300419743,-0.5230416586272608,-0.6834191270255328,-0.815999513981663,-0.9153903026098983,-0.977548909967344,-0.9999471047234172,-0.9816738185577513,-0.9234721556075499,-0.827709068179946,-0.6982788847513993,-0.5404445336423997,-0.36062279001663505,-0.16612207889427807,0.035156802059452895,0.23504529791349657,0.42544444119694164,0.5986619972361811,0.7477367177830418,0.8667377858515952,0.951028804 ...

# %% [markdown]
# ### Approximarea logaritmului natural

# %%
from tema1 import approx_ln

x = np.linspace(0.01, 100, 1000)

y = [approx_ln(x_value) for x_value in x]
fig = go.Figure(data=go.Scatter(x=x, y=y, name="polynomial approx method"))

y = [np.log(x_value) for x_value in x]
fig.add_trace(go.Scatter(x=x, y=y, name="numpy ln method"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bd377673-9e66-4dc5-9677-fc3ac9928b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b